# %% [markdown]
# This file allows you to watch wat was said using a comment ID to see if the text make sence

# %%
import pandas as pd

# %%
data_path = 'Largedata/links2022.ndjson'


data_raw = pd.read_json(data_path, lines=True)

# %%
id_list =['d4c95gr']
data = data_raw[data_raw['id'].isin(id_list)]
for comment in data['comment']:
    print(comment)
    print('-------------------')
# Out:
# I always thought Daenerys was very INFJ. What makes you think otherwise?
# -------------------

# %%
id_list = ['dgli9ge', 'dhdx89v', 'dlho7rx', 'dnbqy55', 'dnbs1jh', 'dnphznt', 'e70o2u9', 'daehun2', 'dcj7q0f', 'dhdzuc7', 'dghgxvr', 'dghhai9', 'dghhi6o', 'dghhrkd', 'dghhvx4', 'fzcvfkp', 'e7o9viz', 'e7oaemg', 'duvnxcn', 'dxo10bu', 'dxwiazj', 'dwst0j4', 'fqj0tib', 'h4y7jy6', 'h6tk0nn', 'g0l82zd', 'g79kag9', 'h4hxmdl', 'h4k7hs9', 'gonzrh2', 'gtpb29t', 'hca3lit', 'gzw6u6y', 'gan5ebi', 'g6e52vr', 'g6f683h', 'fr5jzog', 'hhlbyt0', 'g0npw8o', 'frhwsi5', 'hldohzu', 'hjvygds', 'hk22rby', 'e95wz9k', 'eaq7rdu', 'g300tvo', 'e5pb8a7', 'ef3oscz', 'ef3xe22', 'ef63a69', 'efwgxbb', 'elzhuj2', 'f2v3elk', 'fjmaec3', 'f0b9sii', 'f0bdfdh', 'f2rlt3c', 'ez8id8h', 'f1e1mrh', 'fjlaod2', 'gyytrve', 'f6jtkw7', 'f6k6q1l', 'f9jj2nq', 'foq11zr', 'fpogbrm', 'fsusxqc', 'fsuunfz', 'fwutqjy', 'g02ubbg', 'g07zw4m', 'g09lw6l', 'g8orm7j', 'frk14p8', 'fr38jnm', 'fp9iup0', 'fq6kt3j', 'fvx052v', 'frk6vqy', 'frkec85', 'ft1jdac', 'g6goc08', 'g9crzgf', 'ga8wxwa', 'fx6tk71', 'gfuh072', 'fycfik0', 'fyigz5d', 'fz1a8fb', 'fz1sm3k', 'fz1y59h', 'fz211uy', 'fyzc646', 'fz5n6uj', 'g1xtltp', 'g43zipx', 'fglgckt', 'ew1en28', 'eywyhnn', 'f14j1y8', 'f0jmx78', 'f0jmxoh', 'f0wieah', 'f0xtowe', 'f0v0x9t', 'f236phc', 'f1e092p', 'f1e0sdr', 'f9mpf67', 'f1ul3w7', 'fle666v', 'g4rkfud', 'g8bcsjw', 'h244gfi', 'h35ksiz']
#Remove all rows not where the id is in the id_list
data = data_raw[data_raw['id'].isin(id_list)]
for comment in data['comment']:
    print(comment)
    print('-------------------')
# Out:
# Only second best?! Pfft! I think both ISFJ and ESFJ deserve to share the top spot :-)
# -------------------
# My boyfriend is an ISFJ (though seasoned to be more *socially* extraverted) and I adore him to death. Something about you guys so pure hearted, genuine, and generous. Definitely less...broody than us NFJs. Much love to you.
# -------------------
# are you qu4ntum
# -------------------
# unfriended
# -------------------
# kys
# -------------------
# have fun getting mono
# -------------------
# pls no two snowflakes are alike
# -------------------
# Sure, go for it!  Although it would be even more helpful if you could make a video of yourself answering the questions!
# -------------------
# You are the cutest creature alive.
#
# -------------------
# I think ESFJs are awesome, sounds awesome to me.
# -------------------
# I have arrived. 💖
# -------------------
# ISTP?
# -------------------
# Interesting!
#
# ...

# %%
data
# Out:
# Empty DataFrame
# Columns: [out_going, in_going, id, flair, comment]
# Index: []
