# %%
import pickle as pkl
import matplotlib.pyplot as plt
import random
from random import sample 
import pandas as pd
import seaborn as sns
import numpy as np
import re
from wordcloud import WordCloud
import os
import json
from tqdm import tqdm
import networkx as nx
import pickle
# plot mention matrix
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import TfidfVectorizer

# %% [markdown]
# # Wordcloud section
# Main responsible Andreas

# %%
with open(r"LargeData\Graph_all.pkl", 'rb') as file:
    graph = pickle.load(file)

# %%
flair_list = ["intp","intj","entp","entj","infj","infp","enfj","enfp","istj","isfj","estj","esfj","istp","isfp","estp","esfp"]
extended_flair_list = flair_list + ["submissions"]

mention_dict = {}
id_dict = {}
text_dict = {}

for flair in flair_list:
    mention_dict[flair] = 0
    id_dict[flair] = []
    text_dict[flair] = []

for edge in graph.edges:
    author = edge[0]
    addressee = edge[1]

    

    #Check if node is empty
    if graph.nodes[addressee] == {} or graph.nodes[author] == {}:
        continue

    author_flair = graph.nodes[author]['flair']
    addressee_flair = graph.nodes[addressee]['flair']
    if author_flair not in flair_list: 
        continue

    mention_dict[author_flair]+= 1
    id_dict[author_flair].append(graph.edges[edge]['comment_id'])
    text_dict[author_flair].append(graph.edges[edge]['comment'])

for node in graph.nodes:
    if graph.nodes[node] == {}: 
        continue
    author_flair = graph.nodes[node]['flair']
    if author_flair not in flair_list: 
        continue
    mention_dict[author_flair]+= len(graph.nodes[node]['submissions_id'])
    id_dict[author_flair].append(graph.nodes[node]['submissions_id'])
    text_dict[author_flair].append(graph.nodes[node]['submissions'])

# %%
vectorizer = TfidfVectorizer()

#all documents
all = []
for text in text_dict.values():
    all.extend(text)

tf_idf= vectorizer.fit_transform([' '.join(text) for text in all])
#names = list(text_dict.keys())

# %%
# make mega document
types_text = []
for text in text_dict.values():
    types_text.extend(text)

tf_idf = vectorizer.transform([' '.join(text) for text in types_text])
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "c:\Users\Andre\anaconda3\envs\SkabsHumanisme\Lib\site-packages\IPython\core\interactiveshell.py", line 3526, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\Andre\AppData\Local\Temp\ipykernel_17244\1923566495.py", line 6, in <module>
#     tf_idf = vectorizer.transform([' '.join(text) for text in types_text])
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Andre\anaconda3\envs\SkabsHumanisme\Lib\site-packages\sklearn\feature_extraction\text.py", line 2157, in transform
#     X = super().transform(raw_documents)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Andre\anaconda3\envs\SkabsHumanisme\Lib\site-packages\sklearn\feature_extraction\text.py", line 1433, in transform
#     _, X = self._count_vocab(raw_documents, fixed_vocab=True)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Andre\anaconda3\envs\SkabsHumanisme\Lib\site-packages\sklearn\feature_extraction\text.py", line -1, in _count_vocab
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\Andre\anaconda3\envs\SkabsHumanisme\Lib\site-packages\IPython\core\interactiveshell.py", line 2120, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Andre\anaconda3\envs\SkabsHumanisme\Lib\site-packages\IPython\core\ultratb.py", line 1435, in structured_traceback
#     return FormattedTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Andre\anaconda3\envs\SkabsHumanisme\Lib\site-packages\IPython\core\ultratb.py", line 1326, in structured_traceback
#     return VerboseTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Andre\anaconda3\envs\SkabsHumanisme\Lib\site-packages\IPython\core\ultratb.py", line 1173, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Andre\anaconda3\envs\SkabsHumanisme\Lib\site-packages\IPython\core\ultratb.py", line 1088, in format_exception_as_a_whole
#     frames.append(self.format_record(record))
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Andre\anaconda3\envs\SkabsHumanisme\Lib\site-packages\IPython\core\ultratb.py", line 970, in format_record
#     frame_info.lines, Colors, self.has_colors, lvals
#     ^^^^^^^^^^^^^^^^
#   File "c:\Users\Andre\anaconda3\envs\SkabsHumanisme\Lib\site-packages\IPython\core\ultratb.py", line 792, in lines
#     return self._sd.lines
#            ^^^^^^^^^^^^^^
#   File "c:\Users\Andre\anaconda3\envs\SkabsHumanisme\Lib\site-packages\stack_data\utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#                                                ^^^^^^^^^^^^^^
#   File "c:\Users\Andre\anaconda3\envs\SkabsHumanisme\Lib\site-packages\stack_data\core.py", line 698, in lines
#     pieces = self.included_pieces
#              ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Andre\anaconda3\envs\SkabsHumanisme\Lib\site-packages\stack_data\utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#                                                ^^^^^^^^^^^^^^
#   File "c:\Users\Andre\anaconda3\envs\SkabsHumanisme\Lib\site-packages\stack_data\core.py", line 649, in included_pieces
#     pos = scope_pieces.index(self.executing_piece)
#                              ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Andre\anaconda3\envs\SkabsHumanisme\Lib\site-packages\stack_data\utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#                                                ^^^^^^^^^^^^^^
#   File "c:\Users\Andre\anaconda3\envs\SkabsHumanisme\Lib\site-packages\stack_data\core.py", line 628, in executing_piece
#     return only(
#            ^^^^^
#   File "c:\Users\Andre\anaconda3\envs\SkabsHumanisme\Lib\site-packages\executing\executing.py", line 164, in only
#     raise NotOneValueFound('Expected one value, found 0')
# executing.executing.NotOneValueFound: Expected one value, found 0

# %%
def tf_idf_to_string(tf_idf_matrix, word_list):
    feature_index = tf_idf_matrix.nonzero()[1]
    tfidf_scores = [(word_list[i], tf_idf_matrix[0, i]) for i in feature_index]
    tf_idf_string = ''
    for word, score in tfidf_scores:
        tf_idf_string += (word + ' ') * int(score * 100000)  # Multiplying by 10 for better visualization
    return tf_idf_string

data_for_wordcloud = []
for i in range(16):
    data_for_wordcloud.append(tf_idf_to_string(tf_idf[i, :], word_list = vectorizer.get_feature_names_out()))

# %%
fig, ax = plt.subplots(4, 4, figsize=[20, 20])
names = list(text_dict.keys())
for i in range(4):
    for j in range(4):

        wordcloud = WordCloud(background_color='white', width=600, height=400,collocations=False).generate(data_for_wordcloud[4*i+j])
        ax[i,j].imshow(wordcloud)
        ax[i,j].axis('off')
        ax[i,j].set_title(names[4*i+j],fontsize=40)
plt.show()

# %%
fig, ax = plt.subplots(4, 4, figsize=[20, 20])
for i in range(4):
    for j in range(4):

        wordcloud = WordCloud(background_color='white', width=600, height=400,collocations=False).generate(data_for_wordcloud[4*i+j])
        ax[i,j].imshow(wordcloud)
        ax[i,j].axis('off')
        ax[i,j].set_title(names[4*i+j],fontsize=40)
plt.show()

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer(max_df=0.8,min_df=0.2,ngram_range=(2,2))
names = list(text_dict.keys())
tf_idf= vectorizer.fit_transform([' '.join(list) for list in text_dict.values()])
word_list = vectorizer.get_feature_names_out()

# %%
data_for_wordcloud = []
for i in range(16):
    data_for_wordcloud.append(tf_idf_to_string(tf_idf[i, :], word_list))

fig, ax = plt.subplots(4, 4, figsize=[20, 20])
for i in range(4):
    for j in range(4):

        wordcloud = WordCloud(background_color='white', width=600, height=400,collocations=False).generate(data_for_wordcloud[4*i+j])
        ax[i,j].imshow(wordcloud)
        ax[i,j].axis('off')
        ax[i,j].set_title(names[4*i+j],fontsize=40)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\Andre\OneDrive - Danmarks Tekniske Universitet\Social Data Science\Projekt_git\MBTI\4_1_talked_about.ipynb Cell 10 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/Andre/OneDrive%20-%20Danmarks%20Tekniske%20Universitet/Social%20Data%20Science/Projekt_git/MBTI/4_1_talked_about.ipynb#X15sZmlsZQ%3D%3D?line=0'>1</a> data_for_wordcloud = []
#       <a href='vscode-notebook-cell:/c%3A/Users/Andre/OneDrive%20-%20Danmarks%20Tekniske%20Universitet/Social%20Data%20Science/Projekt_git/MBTI/4_1_talked_about.ipynb#X15sZmlsZQ%3D%3D?line=1'>2</a> for i in range(16):
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Andre/OneDrive%20-%20Danmarks%20Tekniske%20Universitet/Social%20Data%20Science/Projekt_git/MBTI/4_1_talked_about.ipynb#X15sZmlsZQ%3D%3D?line=2'>3</a>     data_for_wordcloud.append(tf_idf_to_string(tf_idf[i, :], word_list))
#       <a href='vscode-notebook-cell:/c%3A/Users/Andre/OneDrive%20-%20Danmarks%20Tekniske%20Universitet/Social%20Data%20Science/Projekt_git/MBTI/4_1_talked_about.ipynb#X15sZmlsZQ%3D%3D?line=4'>5</a> fig, ax = plt.subplots(4, 4, figsize=[20, 20])
#       <a href='vscode-notebook-cell:/c%3A/Users/Andre/OneDrive%20-%20Danmarks%20Tekniske%20Universitet/Social%20Data%20Science/Projekt_git/MBTI/4_1_talked_about.ipynb#X15sZmlsZQ%3D%3D?line=5'>6</a> for i in range(4):
#
# c:\Users\Andre\OneDrive - Danmarks Tekniske Universitet\Social Data Science\Projekt_git\MBTI\4_1_talked_about.ipynb Cell 10 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/Andre/OneDrive%20-%20Danmarks%20Tekniske%20Universitet/Social%20Data%20Science/Projekt_git/MBTI/4_1_talked_about.ipynb#X15sZmlsZQ%3D%3D?line=0'>1</a> def tf_idf_to_string(tf_idf_matrix, word_list):
#       <a href='vscode-notebook-cell:/c%3A/Users/Andre/OneDrive%20-%20Danmarks%20Tekniske%20Universitet/Social%20Data%20Science/Projekt_git/MBTI/4_1_talked_about.ipynb#X15sZmlsZQ%3D%3D?line=1'>2</a>     feature_index = tf_idf_matrix.nonzero()[1]
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Andre/OneDrive%20-%20Danmarks%20Tekniske%20Universitet/Social%20Data%20Science/Projekt_git/MBTI/4_1_talked_about.ipynb#X15sZmlsZQ%3D%3D?line=2'>3</a>     tfidf_scores = [(word_list[i], tf_idf_matrix[0, i]) for i in feature_index]
#       <a href='vscode-notebook-cell:/c%3A/Users/Andre/OneDrive%20-%20Danmarks%20Tekniske%20Universitet/Social%20Data%20Science/Projekt_git/MBTI/4_1_talked_about.ipynb#X15sZmlsZQ%3D%3D?line=3'>4</a>     tf_idf_string = ''
#       <a href='vscode-notebook-cell:/c%3A/Users/Andre/OneDrive%20-%20Danmarks%20Tekniske%20Universitet/Social%20Data%20Science/Projekt_git/MBTI/4_1_talked_about.ipynb#X15sZmlsZQ%3D%3D?line=4'>5</a>     for word, score in tfidf_scores:
#
# c:\Users\Andre\OneDrive - Danmarks Tekniske Universitet\Social Data Science\Projekt_git\MBTI\4_1_talked_about.ipynb Cell 10 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/Andre/OneDrive%20-%20Danmarks%20Tekniske%20Universitet/Social%20Data%20Science/Projekt_git/MBTI/4_1_talked_about.ipynb#X15sZmlsZQ%3D%3D?line=0'>1</a> def tf_idf_to_string(tf_idf_matrix, word_list):
#       <a href='vscode-notebook-cell:/c%3A/Users/Andre/OneDrive%20-%20Danmarks%20Tekniske%20Universitet/Social%20Data%20Science/Projekt_git/MBTI/4_1_talked_about.ipynb#X15sZmlsZQ%3D%3D?line=1'>2</a>     feature_index = tf_idf_matrix.nonzero()[1]
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Andre/OneDrive%20-%20Danmarks%20Tekniske%20Universitet/Social%20Data%20Science/Projekt_git/MBTI/4_1_talked_about.ipynb#X15sZmlsZQ%3D%3D?line=2'>3</a>     tfidf_scores = [(word_list[i], tf_idf_matrix[0, i]) for i in feature_index]
#       <a href='vscode-notebook-cell:/c%3A/Users/Andre/OneDrive%20-%20Danmarks%20Tekniske%20Universitet/Social%20Data%20Science/Projekt_git/MBTI/4_1_talked_about.ipynb#X15sZmlsZQ%3D%3D?line=3'>4</a>     tf_idf_string = ''
#       <a href='vscode-notebook-cell:/c%3A/Users/Andre/OneDrive%20-%20Danmarks%20Tekniske%20Universitet/Social%20Data%20Science/Projekt_git/MBTI/4_1_talked_about.ipynb#X15sZmlsZQ%3D%3D?line=4'>5</a>     for word, score in tfidf_scores:
#
# File c:\Users\Andre\anaconda3\envs\SkabsHumanisme\Lib\site-packages\scipy\sparse\_index.py:49, in IndexMixin.__getitem__(self, key)
#      47 if isinstance(row, INT_TYPES):
#      48     if isinstance(col, INT_TYPES):
# ---> 49         return self._get_intXint(row, col)
#      50     elif isinstance(col, slice):
#      51         self._raise_on_1d_array_slice()
#
# File c:\Users\Andre\anaconda3\envs\SkabsHumanisme\Lib\site-packages\scipy\sparse\_compressed.py:656, in _cs_matrix._get_intXint(self, row, col)
#     654 M, N = self._swap(self.shape)
#     655 major, minor = self._swap((row, col))
# --> 656 indptr, indices, data = get_csr_submatrix(
#     657     M, N, self.indptr, self.indices, self.data,
#     658     major, major + 1, minor, minor + 1)
#     659 return data.sum(dtype=self.dtype)
#
# KeyboardInterrupt:
